# %% [markdown]
# <h1><center>Matplotlib subplots Notebook<center><h1>

# %% [markdown]
# ### This will be second Notebook for Matplotlib for data visualization... first one was called Matplotlib basics

# %% [markdown]
# # Importing my libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from matplotlib import rcParams

# %%
rcParams['figure.figsize'] = (16,8)        ## this changes shown plot size

# %% [markdown]
# ## The datasets I will use are in a folder named datasets

# %% [markdown]
# # Plotting figures using subplots

# %%
df1 = pd.read_csv('Datasets/pokemon.csv',index_col='id')
df1
# Out:
#          species  generation_id  height  weight  base_experience    type_1  \
# id
# 1      bulbasaur              1     0.7     6.9               64     grass
# 2        ivysaur              1     1.0    13.0              142     grass
# 3       venusaur              1     2.0   100.0              236     grass
# 4     charmander              1     0.6     8.5               62      fire
# 5     charmeleon              1     1.1    19.0              142      fire
# ..           ...            ...     ...     ...              ...       ...
# 803      poipole              7     0.6     1.8              189    poison
# 804    naganadel              7     3.6   150.0              243    poison
# 805    stakataka              7     5.5   820.0              257      rock
# 806  blacephalon              7     1.8    13.0              257      fire
# 807      zeraora              7     1.5    44.5              270  electric
#
# ...

# %%
height = sorted(df1['height'])
attack = sorted(df1['attack'])
defense = sorted(df1['defense'])

fig, ax = plt.subplots()
ax.plot(height,attack,marker='v',linestyle="None")
ax.plot(height,defense,color='Green')

ax.set_xlabel('height')
ax.set_ylabel('strength')
ax.set_title('Pokemon data')

plt.show()

# %% [markdown]
# # Making many plots

# %%
df1['type_1'].unique()
## I will make from thsi data a new dataset to work on
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
statistics = {'hp':'mean','attack':'mean','defense':'mean','speed':'mean','special-attack':'mean','special-defense':'mean'}
types_data = df1.groupby('type_1').agg(statistics).reset_index()
types_data.rename(columns={'type_1':'type'},inplace=True)
types_data
# Out:
#         type         hp      attack     defense      speed  special-attack  \
# 0        bug  56.722222   67.625000   69.319444  62.319444       56.930556
# 1       dark  72.551724   86.758621   67.413793  74.275862       71.413793
# 2     dragon  75.851852  100.111111   80.703704  75.370370       81.074074
# 3   electric  61.200000   71.350000   60.525000  86.725000       85.025000
# 4      fairy  72.833333   61.000000   67.055556  51.444444       78.722222
# 5   fighting  72.068966   97.482759   65.896552  64.931034       49.931034
# 6       fire  68.433962   83.094340   65.811321  74.566038       84.773585
# 7     flying  68.000000   71.666667   61.666667  96.333333       89.000000
# 8      ghost  62.259259   69.777778   79.148148  58.703704       79.851852
# 9      grass  65.358974   72.538462   70.166667  58.871795       72.756410
# 10    ground  73.187500   93.250000   82.343750  60.750000       51.625000
# ...

# %% [markdown]
# ### For previous data I will plot 3 subplots for: <br>(attack, special-attack), (defense, special-defense), (hp, speed)

# %%
fig, ax = plt.subplots(nrows=3,ncols=1)    # ax is tuple of 3 elements

ax[0].plot(types_data['type'],types_data['attack'],color='#d62d2d')
ax[0].plot(types_data['type'],types_data['special-attack'],color='#5c0606')

ax[1].plot(types_data['type'],types_data['defense'],color='#ccd431')
ax[1].plot(types_data['type'],types_data['special-defense'],color='#70750b')

ax[2].plot(types_data['type'],types_data['hp'],color='#14c75e')
ax[2].plot(types_data['type'],types_data['speed'],color='#313ed4')

plt.show()

# %% [markdown]
# ### For previous data I will plot 6 subplots (3 rows, 2 columns)

# %%
fig, ax = plt.subplots(nrows=3,ncols=2)   

ax[0][0].plot(types_data['type'],types_data['attack'],color='#d62d2d')
ax[0][1].plot(types_data['type'],types_data['special-attack'],color='#5c0606')

ax[1][0].plot(types_data['type'],types_data['defense'],color='#ccd431')
ax[1][1].plot(types_data['type'],types_data['special-defense'],color='#70750b')

ax[2][0].plot(types_data['type'],types_data['hp'],color='#14c75e')
ax[2][1].plot(types_data['type'],types_data['speed'],color='#313ed4')

plt.show()

# %% [markdown]
# ## sharing x-axis and y-axis across subplots

# %%
fig, ax = plt.subplots(nrows=3,ncols=2,sharex=True,sharey=True)   

ax[0][0].plot(types_data['type'],types_data['attack'],color='#d62d2d')
ax[0][1].plot(types_data['type'],types_data['special-attack'],color='#5c0606')

ax[1][0].plot(types_data['type'],types_data['defense'],color='#ccd431')
ax[1][1].plot(types_data['type'],types_data['special-defense'],color='#70750b')

ax[2][0].plot(types_data['type'],types_data['hp'],color='#14c75e')
ax[2][1].plot(types_data['type'],types_data['speed'],color='#313ed4')

plt.show()

# %% [markdown]
# # Plotting Time-Series

# %%
climate_change = pd.read_csv('Datasets/climate_change.csv',index_col='date')
climate_change
# Out:
#                co2  relative_temp
# date
# 1958-03-06  315.71           0.10
# 1958-04-06  317.45           0.01
# 1958-05-06  317.50           0.08
# 1958-06-06     NaN          -0.05
# 1958-07-06  315.86           0.06
# ...            ...            ...
# 2016-08-06  402.27           0.98
# 2016-09-06  401.05           0.87
# 2016-10-06  401.59           0.89
# 2016-11-06  403.55           0.93
# 2016-12-06  404.45           0.81
#
# [706 rows x 2 columns]

# %%
fig, ax = plt.subplots()
ax.plot(climate_change.index,climate_change['co2'])

ax.set_xlabel('Time')
ax.set_ylabel('co2')

plt.show()
## from shape we can observe some nan values

# %%
sixties = climate_change['1960-01-01':'1970-01-01'] # I made a new dataframe with only 1 decade

fig, ax = plt.subplots()
ax.plot(sixties.index,sixties['co2'])

ax.set_xlabel('Time')
ax.set_ylabel('co2')

plt.show()

# %% [markdown]
# # Plotting time-series with different variables

# %%
## Look how will the shape will look here when plotting c02, relative_temp on same y-axis
fig, ax = plt.subplots()

ax.plot(climate_change.index,climate_change['co2'],color='blue')
ax.plot(climate_change.index,climate_change['relative_temp'],color='red')

plt.show()

# %% [markdown]
# ### Here relative_temp don't look so good and that is because y-values of co2 is much higher <br> So to put them in same curve we could make y-axis for every one

# %%
fig, ax = plt.subplots()

ax.plot(climate_change.index,climate_change['co2'],color='blue')
ax.set_xlabel('Time')
ax.set_ylabel('co2')

ax2 = ax.twinx()                  ## this makes ax2 uses same x-axis of ax
ax2.plot(climate_change.index,climate_change['relative_temp'],color='red')
ax2.set_ylabel('relative temprature')

plt.show()
# left y-axis for co2
# right y-axis for relative temp

# %% [markdown]
# ### You can also change color of every y-axis to make it easy to visualize

# %%
fig, ax = plt.subplots()

ax.plot(climate_change.index,climate_change['co2'],color='blue')
ax.set_xlabel('Time')
ax.set_ylabel('co2',color='blue')
ax.tick_params('y',colors='blue')      # this changes color of ticks

ax2 = ax.twinx()
ax2.plot(climate_change.index,climate_change['relative_temp'],color='red')
ax2.set_ylabel('relative temprature',color='red')
ax2.tick_params('y',colors='red')

plt.show()

# %% [markdown]
# # Using functions

# %% [markdown]
# ### We noticed in the last examples that I repeat the same code many times <br> So to avoid so I can make function that will do so for me

# %%
def plot_time_series(axes, x, y, my_color, my_xlabel, my_ylabel):
    axes.plot(x, y , color=my_color)
    axes.set_xlabel(my_xlabel,color=my_color)
    axes.set_ylabel(my_ylabel,color=my_color)
    axes.tick_params('y',colors=my_color)
    
## This function will make me plot same figure faster

# %%
fig, ax = plt.subplots()

plot_time_series(ax, climate_change.index, climate_change['co2'], 'blue', 'Time (years)', 'CO2 levels')
ax2 = ax.twinx()
plot_time_series(ax2, climate_change.index, climate_change['relative_temp'], 'red', 'Time (years)', 'Relative temperature (Celsius)')

plt.show()

# %% [markdown]
# # Annotating time series data

# %% [markdown]
# ### It is usually a small pieces of text that describes a particular part of data

# %% [markdown]
# ### For the previous graph I will add text to represent data > 1 degree relative temprature

# %%
fig, ax = plt.subplots()

plot_time_series(ax, climate_change.index, climate_change['co2'], 'blue', 'Time (years)', 'CO2 levels')
ax2 = ax.twinx()
plot_time_series(ax2, climate_change.index, climate_change['relative_temp'], 'red', 'Time (years)', 'Relative temperature (Celsius)')

ax2.annotate("more than 1 degree",             ## Text to display
             xy=(("2015-10-06"), 1))           ## coordinates of point I want to display on here (x = 2015-10-06, y = 1)

plt.grid()
plt.show()
# look at point x = 2015-10-06, y = 1 , you will see a written text more than 1

# %% [markdown]
# #### But the shape written word place is not good so I will change its place

# %%
fig, ax = plt.subplots()

plot_time_series(ax, climate_change.index, climate_change['co2'], 'blue', 'Time (years)', 'CO2 levels')
ax2 = ax.twinx()
plot_time_series(ax2, climate_change.index, climate_change['relative_temp'], 'red', 'Time (years)', 'Relative temperature (Celsius)')

ax2.annotate("more than 1 degree",             ## Text to display
             xy=(("2015-10-06"), 1),          ## coordinates of point I want to display on here (x = 2015-10-06, y = 1)
             xytext=("2010-10-06",0),       ## coordinates of point I want to show text at
             arrowprops = {'arrowstyle':'->','color':'green'}  ## this shows arrow 
            ## note if you made arrowprops = {} it will draw normal arrow without styles
            )  

plt.grid()
plt.show()
# look at point x = 2010-10-06, y = 0 , you will see a written text more than 1

# %% [markdown]
# ## Ok I know that such concept is hard so I will illustrate it again but on sine wave

# %% [markdown]
# ### I will create a function named sine_wave that when called It will plot a sine wave function of 1 period from:<br> 0 to 2 pi

# %%
pi = np.pi
def sine_wave():
    x = np.linspace(0, 2*pi, 101)
    y = np.sin(x)

    plt.plot(x,y,color='#0398fc')

    plt.title('Sine Wave', color='#0398fc',size=40)
    plt.xlabel('X (rad)',color='#0398fc',size=30)
    plt.ylabel('y',color='#0398fc',size=30)

    plt.xlim([0, 2*pi])             # makes my x-axis from 0 to 2 pi only
    plt.ylim([-1.2, 1.2])

    plt.grid()

# %%
sine_wave()
plt.show()

# %% [markdown]
# ### Now I want to specify local max and min points which are from math:<br> max: 0.5 pi <br> min: 1.5 pi

# %%
## putting markers at those points
def sine_wave_with_markers():            # function for sine wave with the markers
    sine_wave()
    plt.plot(0.5*pi,1,color='red',marker='o',markersize=5)
    plt.plot(1.5*pi,-1,color='red',marker='o',markersize=5)

sine_wave_with_markers()
plt.show()

## NOTE THAT 
## I could have done that with one function but in a purpose of showing how everything works I made thim in several functions

# %% [markdown]
# ### Now I want to add text and arrows to this points

# %%
sine_wave_with_markers()

plt.annotate("Local max point",                               ## Text to display
             xy = (0.5*pi,1),                                 ## point coordinates
             xytext = (pi,1.1),                               ## text coordinates
             arrowprops = {'arrowstyle':'->','color':'red'}   ## arrow
)

plt.annotate("Local min point",                               ## Text to display
             xy = (1.5*pi,-1),                                ## point coordinates
             xytext = (pi,-1.1),                              ## text coordinates
             arrowprops = {'arrowstyle':'->','color':'red'}   ## arrow
)

plt.show()

# %% [markdown]
#  <h1><u> Quantitative comparisons <u>

# %% [markdown]
# # barplot

# %%
medals = pd.read_csv('Datasets/medals_by_country_2016.csv',index_col='Unnamed: 0')
medals
# Out:
#                Bronze  Gold  Silver
# United States      67   137      52
# Germany            67    47      43
# Great Britain      26    64      55
# Russia             35    50      28
# China              35    44      30
# France             21    20      55
# Australia          25    23      34
# Italy              24     8      38
# Canada             61     4       4
# Japan              34    17      13

# %%
fig, ax = plt.subplots()
ax.bar(medals.index,medals['Gold'])
ax.set_ylabel('Medals')

plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(medals.index,medals['Gold'])
ax.bar(medals.index,medals['Silver'],bottom=medals['Gold'])  # If I didn't add bottom blue bars may be unvisable
ax.bar(medals.index,medals['Bronze'],bottom=medals['Gold']+medals['Silver'])
ax.set_ylabel('Medals')

ax.legend(['Gold','Silver','Bronze'])
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# ### First I will do some cleaning .....<br>Where I will make new dataframes which are :
# > men_rowing (contains data for men in rowing sport)<br>
# > men_gymnastics (contains data for men in gymnastics sport)

# %%
olympics = pd.read_csv('Datasets/summer2016.csv',index_col='Unnamed: 0')
olympics
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 158         62                Giovanni Abagnale   M  21.0   198.0    90.0
# 161         65                Patimat Abakarova   F  21.0   165.0    49.0
# 175         73                        Luc Abalo   M  31.0   182.0    86.0
# 450        250             Saeid Morad Abdevali   M  26.0   170.0    80.0
# 794        455      Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# ...        ...                              ...  ..   ...     ...     ...
# 269511  134857                         Zhu Ting   F  21.0   198.0    78.0
# 270111  135132                    Bojana ivkovi   F  28.0   186.0    72.0
# 270281  135205  Shakhobiddin Shokirovich Zoirov   M  23.0   169.0    52.0
# 270370  135245                     Milenko Zori   M  27.0   179.0    73.0
# 271019  135525                   Martin Zwicker   M  29.0   175.0    64.0
#
#               Team  NOC        Games  Year  Season            City  \
# ...

# %%
men_rowing = olympics[(olympics['Sport'] == 'Rowing') & (olympics['Sex'] == 'M')]
men_rowing
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 158         62             Giovanni Abagnale   M  21.0   198.0    90.0
# 11648     6346                    Jrmie Azou   M  27.0   178.0    71.0
# 14871     8025  Thomas Gabriel Jrmie Baroukh   M  28.0   183.0    70.0
# 15215     8214            Jacob Jepsen Barse   M  27.0   188.0    73.0
# 18441     9764          Alexander Belonogoff   M  26.0   187.0    90.0
# ...        ...                           ...  ..   ...     ...     ...
# 252281  126330               Giuseppe Vicino   M  23.0   195.0    95.0
# 258859  129601                Phillipp Wende   M  31.0   199.0    90.0
# 260260  130259        Peter Noel Jan Wiersum   M  31.0   173.0    55.0
# 260338  130298                   Tone Wieten   M  22.0   201.0   102.0
# 261973  131072       Kasper Winther Jrgensen   M  31.0   182.0    73.0
#
#                Team  NOC        Games  Year  Season            City   Sport  \
# ...

# %%
men_gymnastics = olympics[(olympics['Sport'] == 'Gymnastics') & (olympics['Sex'] == 'M')]
men_gymnastics
# Out:
#             ID                              Name Sex   Age  Height  Weight  \
# 794        455       Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 796        455       Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 797        455       Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 18577     9829        David Sagitovich Belyavsky   M  24.0   165.0    55.0
# 18579     9829        David Sagitovich Belyavsky   M  24.0   165.0    55.0
# 53763    27572                        Deng Shudi   M  24.0   163.0    58.0
# 89224    45219                   Fabian Hambchen   M  28.0   164.0    62.0
# 101753   51457              Diego Matias Hyplito   M  30.0   170.0    68.0
# 114515   57997                       Ryohei Kato   M  22.0   162.0    54.0
# 128700   64787       Nikolay Yulyevich Kuksenkov   M  27.0   172.0    65.0
# 137853   69285       Danell Johan Leyva Gonzalez   M  24.0   170.0    68.0
# ...

# %%
fig, ax = plt.subplots()
ax.hist(men_rowing['Height'])
ax.hist(men_gymnastics['Height'])
ax.set_xlabel('Height in cm')
ax.set_ylabel('number of observations')
ax.legend(['Rowing','Gymnastics'])
plt.show()

# %% [markdown]
# ### Changing bins

# %%
fig, ax = plt.subplots()
ax.hist(men_rowing['Height'],bins=[150,160,170,180,190,200,210])
ax.hist(men_gymnastics['Height'],bins=[150,160,170,180,190,200,210])

ax.set_xlabel('Height in cm')
ax.set_ylabel('number of observations')
ax.legend(['Rowing','Gymnastics'])
plt.show()

## the plot don't look very good so good so I will change histtype to step

# %%
fig, ax = plt.subplots()
ax.hist(men_rowing['Height'],bins=[150,160,170,180,190,200,210],histtype="step")
ax.hist(men_gymnastics['Height'],bins=[150,160,170,180,190,200,210],histtype="step")

ax.set_xlabel('Height in cm')
ax.set_ylabel('number of observations')
ax.legend(['Rowing','Gymnastics'])
plt.show()

# %% [markdown]
# # Statistical Plots

# %% [markdown]
# ## This kind of plots helps me to see statistical summary for my data like mean and std}

# %%
fig, ax = plt.subplots()

ax.bar('Rowing',
       men_rowing['Height'].mean(),
       yerr = men_rowing['Height'].std()
      )

ax.bar('Gymnastics',
       men_gymnastics['Height'].mean(),
       yerr = men_gymnastics['Height'].std()
      )

plt.show()

## The shaded area represents the std

# %% [markdown]
# ## Adding error bars to plots

# %%
height = sorted(df1['height'])
attack = sorted(df1['attack'])

fig, ax = plt.subplots()
ax.errorbar(height,attack,marker='o',
       yerr=df1['attack'].std()
       )

ax.set_xlabel('height')
ax.set_ylabel('strength')
ax.set_title('Pokemon data')

plt.show()

## Now every point got error bar representing std

# %% [markdown]
# ## Adding boxplot

# %%
fig, ax = plt.subplots()

ax.boxplot([men_rowing['Height'],men_gymnastics['Height']])
ax.set_xticklabels(['Rowing','Gymnastics'])

plt.show()

# %% [markdown]
# # Scatterplot

# %%
climate_change
# Out:
#                co2  relative_temp
# date
# 1958-03-06  315.71           0.10
# 1958-04-06  317.45           0.01
# 1958-05-06  317.50           0.08
# 1958-06-06     NaN          -0.05
# 1958-07-06  315.86           0.06
# ...            ...            ...
# 2016-08-06  402.27           0.98
# 2016-09-06  401.05           0.87
# 2016-10-06  401.59           0.89
# 2016-11-06  403.55           0.93
# 2016-12-06  404.45           0.81
#
# [706 rows x 2 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(climate_change['co2'],climate_change['relative_temp'])

ax.set_xlabel('CO2 (ppm)')
ax.set_ylabel('relative temp (celsius)')

plt.show()

# %% [markdown]
# ## customizing scatter plots

# %%
eighties = climate_change['1980-01-01':'1990-01-01']
nineties = climate_change['1990-01-01':'2000-01-01']

fig, ax = plt.subplots()

ax.scatter(eighties['co2'],eighties['relative_temp'],color='#0398fc')
ax.scatter(nineties['co2'],nineties['relative_temp'],color='#fc0303')

ax.set_xlabel('c02 (ppm)')
ax.set_ylabel('relative temp (celsius)')
ax.legend(['eighties','nineties'])

plt.show()

# %% [markdown]
# ## Encoding third variable by color

# %%
fig, ax = plt.subplots()

ax.scatter(climate_change['co2'],climate_change['relative_temp'],c=climate_change.index.astype('datetime64[ns]'))
# I changed climate_change type to datetime64[ns] because before it was object so it can't be color code

ax.set_xlabel('CO2 (ppm)')
ax.set_ylabel('Relative temperature (C)')

plt.show()

# %% [markdown]
# # Changing Plot style
# #### It was said in the previous notebook but I will say it again here rapidly

# %%
plt.style.use('ggplot')
height = sorted(df1['height'])
attack = sorted(df1['attack'])
defense = sorted(df1['defense'])

fig, ax = plt.subplots()
ax.plot(height,attack,marker='v',linestyle="None")
ax.plot(height,defense,color='Green')

ax.set_xlabel('height')
ax.set_ylabel('strength')
ax.set_title('Pokemon data')

plt.show()

# %% [markdown]
# ## To return to defult:

# %%
plt.style.use('default')
height = sorted(df1['height'])
attack = sorted(df1['attack'])
defense = sorted(df1['defense'])

fig, ax = plt.subplots()
ax.plot(height,attack,marker='v',linestyle="None")
ax.plot(height,defense,color='Green')

ax.set_xlabel('height')
ax.set_ylabel('strength')
ax.set_title('Pokemon data')

plt.show()

# %% [markdown]
# # Guidelines for choosing plotting style
# > - Dark backgrounds are usually less visible<br><br>
# > - If color is important, consider choosing colorblind-friendly options<br><br>
# > - "seaborn-colorblind" or "tableau-colorblind10"<br><br>
# > - If you think that someone will want to print your gure, use less ink <br><br>
# > - If it will be printed in black-and-white, use the "grayscale" style

# %% [markdown]
# # Saving plots

# %%
sine_wave_with_markers()

plt.annotate("Local max point",                               
             xy = (0.5*pi,1),                                 
             xytext = (pi,1.1),                               
             arrowprops = {'arrowstyle':'->','color':'red'}   
)

plt.annotate("Local min point",                               
             xy = (1.5*pi,-1),                                
             xytext = (pi,-1.1),                              
             arrowprops = {'arrowstyle':'->','color':'red'}   
)

plt.savefig('Sine_Wave.png')  ## Now this will be saved as png

# %%
image1 = Image.open('Sine_Wave.png')
display(image1)
# I opened the image from the computer
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480 at 0x24517ED9D30>

# %% [markdown]
# # Size

# %%
plt.style.use('default')
height = sorted(df1['height'])
attack = sorted(df1['attack'])
defense = sorted(df1['defense'])

fig, ax = plt.subplots()
ax.plot(height,attack,marker='v',linestyle="None")
ax.plot(height,defense,color='Green')

ax.set_xlabel('height')
ax.set_ylabel('strength')
ax.set_title('Pokemon data')


fig.set_size_inches([20,5])        # here Iam setting size
plt.show()

# %% [markdown]
# # Automating figures from data

# %%
sports = olympics['Sport'].unique()
sports

# Now I want to make bar chart fro all this data with height
# Out:
# array(['Rowing', 'Taekwondo', 'Handball', 'Wrestling', 'Gymnastics',
#        'Swimming', 'Basketball', 'Boxing', 'Volleyball', 'Athletics',
#        'Rugby Sevens', 'Judo', 'Rhythmic Gymnastics', 'Weightlifting',
#        'Equestrianism', 'Badminton', 'Water Polo', 'Football', 'Fencing',
#        'Shooting', 'Sailing', 'Beach Volleyball', 'Canoeing', 'Hockey',
#        'Cycling', 'Tennis', 'Diving', 'Table Tennis', 'Triathlon',
#        'Archery', 'Synchronized Swimming', 'Modern Pentathlon',
#        'Trampolining', 'Golf'], dtype=object)

# %%
fig, ax = plt.subplots()
for sport in sports:
    sport_df = olympics[olympics['Sport'] == sport]
    ax.bar(sport,
          sport_df['Height'].mean(),
          yerr = sport_df['Height'].std()
          )

ax.set_ylabel('Height (CM)')
fig.set_size_inches([20,10])
plt.xticks(sports,rotation=90)
plt.show()

# %% [markdown]
# <h1><center> And this is the End of this Notebook <br> For more plots for matplotlib you can visit Matplotlib gallery <br> There You will find all what you will need
