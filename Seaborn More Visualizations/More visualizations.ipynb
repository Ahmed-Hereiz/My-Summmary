# %% [markdown]
# <h1><center> More Visualizations using Seaborn

# %% [markdown]
# # First importing my libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from colorama import Fore  # optional library ( it only helps to change color of printed texts using print() )

# %% [markdown]
# # to plot histogram on seaborn

# %%
school_data = pd.read_csv('Datasets/schoolimprovement2010grants.csv',index_col='Unnamed: 0')
school_data
# Out:
#                            School Name        City State  \
# 0    HOGARTH KINGEEKUK MEMORIAL SCHOOL    SAVOONGA    AK
# 1                      AKIACHAK SCHOOL    AKIACHAK    AK
# 2                       GAMBELL SCHOOL     GAMBELL    AK
# 3                 BURCHELL HIGH SCHOOL     WASILLA    AK
# 4                         AKIAK SCHOOL       AKIAK    AK
# ..                                 ...         ...   ...
# 826             MOUNT HOPE HIGH SCHOOL  MOUNT HOPE    WV
# 827            GEARY ELEMENTARY SCHOOL   LEFT HAND    WV
# 828                TRIUMPH HIGH SCHOOL    CHEYENNE    WY
# 829      HEM JUNIOR/SENIOR HIGH SCHOOL       HANNA    WY
# 830              ROOSEVELT HIGH SCHOOL      CASPER    WY
#
#                                  District Name  Model Selected  Award_Amount  \
# 0                BERING STRAIT SCHOOL DISTRICT  Transformation        471014
# 1                       YUPIIT SCHOOL DISTRICT  Transformation        520579
# ...

# %%
sns.histplot(school_data['Award_Amount'])

plt.show()

# %% [markdown]
# ## you can make displot which will help u to specify the kind also

# %%
print('with no kind parameter :')
sns.displot(school_data['Award_Amount'], bins=20) ## if u made no kind it will plot histogram
plt.show()


print('with kind parameter :')
sns.displot(school_data['Award_Amount'], kind = 'kde') ## KDE : Kernel density estimation
plt.show()
# Out:
# with no kind parameter :
# with kind parameter :

# %%
sns.displot(school_data['Award_Amount'], kde=True, bins=10)
## that will help to analyze data 

plt.show()

# %%
sns.displot(school_data['Award_Amount'], kind='kde', rug=True, fill=True)

plt.show()

# %% [markdown]
# ## NOTE : THIS MEANS THAT
# ## displot has many functions kinds like: kdeplot, rugplot,ecdfplot

# %% [markdown]
# ### ecdf shows cumulative distrubution of data

# %%
sns.displot(school_data['Award_Amount'], kind='ecdf')  

plt.show()

# %% [markdown]
# #  Linear regression ploting
# ## the function for it is regplot

# %%
insurance = pd.read_csv('Datasets/insurance_premiums.csv')
insurance
# Out:
#                    State  fatal_collisions  fatal_collisions_speeding  \
# 0                Alabama              18.8                         39
# 1                 Alaska              18.1                         41
# 2                Arizona              18.6                         35
# 3               Arkansas              22.4                         18
# 4             California              12.0                         35
# 5               Colorado              13.6                         37
# 6            Connecticut              10.8                         46
# 7               Delaware              16.2                         38
# 8   District of Columbia               5.9                         34
# 9                Florida              17.9                         21
# 10               Georgia              15.6                         19
# 11                Hawaii              17.5                         54
# ...

# %%
sns.regplot(x='insurance_losses',y="premiums",data=insurance)    ## it plots points and line showing the linear regression

## it is like linear regression algorithm used in ml
## it is what plots the linear regression

plt.show()

# %% [markdown]
# ## now for linear regression it will be more better `to use lmplot`
# ### I will plot both of them and you will see that they gives the same results but lmplot will give us more options as we can add more parameters

# %%
sns.regplot(x='insurance_losses',y="premiums",data=insurance)
print(Fore.BLUE + 'Using regplot :')   # Fore.BLUE will change color of printed text to blue
plt.show()
## ------------------------------------------------------------------------------------------ ##
sns.lmplot(x='insurance_losses',y="premiums",data=insurance)
print(Fore.BLUE + 'Using lmplot :')    # Fore.BLUE will change color of printed text to blue
plt.show()
## ------------------------------------------------------------------------------------------ ##

# both of them are same with diferent styles
# Out:
# Using regplot :
# Using lmplot :

# %% [markdown]
# ## For lmplot:
# ### it can also get more parameters like hue and col
# ### assuming we have 2 types it will help to better visualize them like :

# %%
sns.lmplot(x='insurance_losses',y="premiums",data=insurance,hue='Region')
print(Fore.BLUE + 'using hue for third parameter :')
plt.show()
## ----------------------------------------------------------------------- ##
sns.lmplot(x='insurance_losses',y="premiums",data=insurance,col='Region')
print(Fore.BLUE + 'using col for third parameter (which is better here) :')
plt.show()
# Out:
# using hue for third parameter :
# using col for third parameter (which is better here) :

# %%
sns.lmplot(x='insurance_losses',y="premiums",data=insurance,row='Region')
print(Fore.BLUE + 'using row for third parameter :')
plt.show()
# Out:
# using row for third parameter :

# %% [markdown]
# # Styles in seaborn

# %% [markdown]
# ## Use .set() method to make style as default

# %%
sns.set()
sns.histplot(school_data['Award_Amount'])

plt.show()

# %% [markdown]
# ## Use .set_style() method to choose a style

# %%
sns.set_style('white')
sns.histplot(school_data['Award_Amount'])

plt.show()

# %% [markdown]
# ## Removing axes

# %%
sns.histplot(school_data['Award_Amount'])
sns.despine(left=True) 
print(Fore.BLUE + 'Remove left axis:')
plt.show()
## -------------------------------------------- ##
sns.histplot(school_data['Award_Amount'])
sns.despine(bottom=True)
print(Fore.BLUE + 'Remove bottom axis:')

plt.show()
# Out:
# Remove left axis:
# Remove bottom axis:

# %% [markdown]
# # Colors in seaborn

# %% [markdown]
# ### since seaborn is built over matplotlib... we can use color_codes of matplotlib

# %%
sns.set(color_codes=True) 
sns.set_style('white')

sns.regplot(x='insurance_losses',y="premiums",data=insurance,color='r')
print(Fore.RED + 'Using regplot :')   # Fore.RED will change color of printed text to red
plt.show()
# Out:
# Using regplot :

# %% [markdown]
# ### and as before you can use set_palette
# ### for making custom colors u can use palplot

# %%
sns.palplot(sns.color_palette("Blues",16)) ## 16 is number of colors that is made
sns.palplot(sns.color_palette("turbo",16)) ## 16 is number of colors that is made

# %% [markdown]
# #### Instead of Blues you can put:
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r

# %% [markdown]
# #### You can use set_palettes also (mentioned in the previous Notebook)

# %% [markdown]
# # customizing axes

# %%
fig, ax = plt.subplots()   
sns.histplot(school_data['Award_Amount'], ax=ax)
ax.set(xlabel="The award amount",ylabel='count',xlim=(0,1000000),title="school data")

plt.show()

# %% [markdown]
# <h1><center>	 The plot types in seaborn

# %% [markdown]
# # Group(1)
# -----------------
#
# > -stripplot()<br>
# > -swarmplot()
#
#
# # Group(2)
# ------------------
#
#
# > -boxplot()<br>
# > -violinplot()<br>
# > -boxenplot()
#
#
# # Group(3)
# ----------------
# (statistical estimates)
#
# > -barplot()<br>
# > -pointplot()<br>
# > -countplot()
#
#
# ## each plot of these has its own parameters and algorithms and way of ploting
# ## you can return to seaborn documentation to learn more about it

# %% [markdown]
# <br>  <br>  <br>  <br>  <br>  <br>  <br>

# %% [markdown]
# # Regression Plots

# %% [markdown]
# ### As you know in ML order matters while fitting.... Some times it is better to fit by 2nd degree so we will learn 2 important functions which are:<br>
# > - regplot()<br>
# > - residplot()
# ### For regplot() it plots the all points of dataset and regression curve fitting them.... <br>While residplot() will be very helpfull to see if your model is good fit or no

# %%
bike_data = pd.read_csv('Datasets/bike_share.csv')
bike_data
# Out:
#          dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0    2011-01-01       1   0     1        0        6           0           2
# 1    2011-01-02       1   0     1        0        0           0           2
# 2    2011-01-03       1   0     1        0        1           1           1
# 3    2011-01-04       1   0     1        0        2           1           1
# 4    2011-01-05       1   0     1        0        3           1           1
# ..          ...     ...  ..   ...      ...      ...         ...         ...
# 726  2012-12-27       1   1    12        0        4           1           2
# 727  2012-12-28       1   1    12        0        5           1           2
# 728  2012-12-29       1   1    12        0        6           0           2
# 729  2012-12-30       1   1    12        0        0           0           1
# 730  2012-12-31       1   1    12        0        1           1           2
#
# ...

# %%
sns.regplot(data=bike_data,x='temp',y='total_rentals')
plt.show()    ## first degree fit

# %% [markdown]
# ### For previous plot residplot() will help me to know if choosing 1st degree fit is good or no

# %%
sns.residplot(data=bike_data,x='temp',y='total_rentals')
print(Fore.BLUE + 'The shape her looks to have slight curve')
plt.show()

# data should be randomly plotted arround mid line but here data looks like it has slight curve 
# so I will see residplot() with order=2 to see if it is better

sns.residplot(data=bike_data,x='temp',y='total_rentals',order=2,color='g')
print(Fore.GREEN + 'The shape her looks more randomly distributed which is better ')
print(Fore.GREEN + 'So it will be better to use 2nd degree in fitting')
plt.show()
# Out:
# The shape her looks to have slight curve
# The shape her looks more randomly distributed which is better
# So it will be better to use 2nd degree in fitting

# %%
sns.regplot(data=bike_data,x='temp',y='total_rentals',order=2,color='g')
plt.show()    ## second degree fit

# %% [markdown]
# ### And this looks much better so our degree will be 2nd degree

# %% [markdown]
# ## Plotting with Categorical values

# %%
sns.regplot(data=bike_data,x='mnth',y='total_rentals',order=2)
print(Fore.BLUE + 'Without jitter:')
plt.show()   

## x_jitter can make it more randomized

sns.regplot(data=bike_data,x='mnth',y='total_rentals',order=2, x_jitter=0.1,color='y')
print(Fore.YELLOW + 'With little jitter:')
plt.show()  

sns.regplot(data=bike_data,x='mnth',y='total_rentals',order=2, x_jitter=0.5,color='r')
print(Fore.RED + 'With large jitter:')
plt.show()
# Out:
# Without jitter:
# With little jitter:
# With large jitter:

# %% [markdown]
# ## Using Estimator
# #### Used for highligiting trends

# %%
sns.regplot(data=bike_data,x='mnth',y='total_rentals',order=2,x_estimator=np.mean)
print(Fore.BLUE + 'estimator uses mean:')
plt.show()   

sns.regplot(data=bike_data,x='mnth',y='total_rentals',order=2,x_estimator=np.median,color='r')
print(Fore.RED + 'estimator uses median:')
plt.show()
# Out:
# estimator uses mean:
# estimator uses median:

# %% [markdown]
# ## We can even divide this data into bins:

# %%
sns.regplot(data=bike_data,x='temp',y='total_rentals',order=1,x_bins=4)
plt.show()

sns.regplot(data=bike_data,x='temp',y='total_rentals',order=2,x_bins=4)
plt.show()

# %% [markdown]
# # Matrix Plot
# ### To do a heatmap() we will need a matrix of data so we will use crosstab() from pandas to do so

# %%
bike_data
# Out:
#          dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0    2011-01-01       1   0     1        0        6           0           2
# 1    2011-01-02       1   0     1        0        0           0           2
# 2    2011-01-03       1   0     1        0        1           1           1
# 3    2011-01-04       1   0     1        0        2           1           1
# 4    2011-01-05       1   0     1        0        3           1           1
# ..          ...     ...  ..   ...      ...      ...         ...         ...
# 726  2012-12-27       1   1    12        0        4           1           2
# 727  2012-12-28       1   1    12        0        5           1           2
# 728  2012-12-29       1   1    12        0        6           0           2
# 729  2012-12-30       1   1    12        0        0           0           1
# 730  2012-12-31       1   1    12        0        1           1           2
#
# ...

# %%
to_heat_map = pd.crosstab(bike_data['mnth'],        # mnth will be on rows (take average of total_rentals)
            bike_data['weekday'],             # weekday will be on cols (take average of total_rentals)
            values=bike_data['total_rentals'],  # making our values from total_rentals
            aggfunc='mean'                         # taking mean of total_rentals
           ).round(0)                              # making value rounded

to_heat_map
# Out:
# weekday       0       1       2       3       4       5       6
# mnth
# 1        1816.0  1927.0  2568.0  2139.0  2513.0  2446.0  1957.0
# 2        2248.0  2604.0  2824.0  2813.0  2878.0  2933.0  2266.0
# 3        3301.0  3546.0  3574.0  3670.0  3817.0  3926.0  3939.0
# 4        4417.0  4516.0  4556.0  4331.0  4764.0  4387.0  4446.0
# 5        5320.0  4512.0  5025.0  5119.0  5893.0  5751.0  5978.0
# 6        5940.0  5478.0  5681.0  5701.0  5622.0  5616.0  6344.0
# 7        5298.0  5792.0  5844.0  5814.0  5624.0  5406.0  5232.0
# 8        4703.0  5518.0  5930.0  6077.0  6038.0  5958.0  5224.0
# 9        6160.0  5637.0  5184.0  5668.0  5486.0  5747.0  6394.0
# 10       4735.0  4632.0  5065.0  5505.0  5537.0  5623.0  5445.0
# 11       4126.0  4658.0  4040.0  4136.0  3994.0  4524.0  4288.0
# 12       2740.0  3498.0  3713.0  3270.0  3711.0  3742.0  3195.0

# %% [markdown]
# ### Now this shape is ready for being a heatmap

# %%
sns.heatmap(to_heat_map)
plt.show()

# %% [markdown]
# ## Customizing Heatmaps

# %%
to_heat_map = to_heat_map.astype('int')    # changing data to int 

sns.heatmap(to_heat_map,           # data to plot
           annot=True,             # makes annotating True
           fmt='d',                # results will be integers
           cmap='ocean',           # cmap (makes colors for cells)
           cbar=True,              # Vertical bar   
           linewidths=0.1,         
           )
plt.show()

## ------------------------------------------------------------------ ## 

## changing in formats:

sns.heatmap(to_heat_map,           # data to plot
           annot=False,             # makes annotating True
           fmt='d',                # results will be integers
           cmap='crest',           # cmap (makes colors for cells)
           cbar=False,              # Vertical bar   
           linewidths=0.6,         
           )
print('There is no numbers because annot=false')
plt.show()

## ------------------------------------------------------------------ ## 

## changing in formats:

sns.heatmap(to_heat_map,           # data to plot
           annot=True,             # makes annotating True
           fmt='d',                # results will be integers
           cmap='Set3',           # cmap (makes colors for cells)
           cbar=False,              # Vertical bar   
           linewidths=10,         
           )
print('Look how line width increased between cells')
plt.show()
# Out:
# There is no numbers because annot=false
# Look how line width increased between cells

# %% [markdown]
# ### Heatmap is also used in representing correlations between columns

# %%
my_cols = ['total_rentals', 'temp', 'casual', 'hum', 'windspeed']
sns.heatmap(bike_data[my_cols].corr(),cmap='Blues')
plt.show()

# %% [markdown]
# # Facetgrid

# %% [markdown]
# #### One of Seaborn's most powerful features is its ability to combine multiple smaller plots into a larger visualization that can help identify trends in data with many variables.
# #### Seaborn's FacetGrid manages the back end data manipulations to make sure that the data is split across rows, columns, and hue, and then used to make the appropriate plot type. The key point to remember is that FacetGrid() provides a lot of flexibility, but you must use a two step process of defining the Facets and mapping the plot type.

# %%
pd.set_option('display.max_columns', None)

college_data = pd.read_csv('Datasets/college_datav3.csv')
college_data
# Out:
#                                                  INSTNM    OPEID  REGION  \
# 0                              Alabama A & M University   100200       5
# 1                   University of Alabama at Birmingham   105200       5
# 2                                    Amridge University  2503400       5
# 3                   University of Alabama in Huntsville   105500       5
# 4                              Alabama State University   100500       5
# ...                                                 ...      ...     ...
# 6697          SAE Institute of Technology San Francisco  4205801       8
# 6698                  Rasmussen College - Overland Park   869423       4
# 6699  National Personal Training Institute of Cleveland  4220901       3
# 6700  Bay Area Medical Academy - San Jose Satellite ...  4223701       8
# 6701                        High Desert Medical College  4228101       8
#
#       SAT_AVG_ALL  PCTPELL  PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL  \
# ...

# %% [markdown]
# ## FacetGrid for categorical plot

# %%
g = sns.FacetGrid(data=college_data,col='HIGHDEG')
g.map(sns.boxplot,'Tuition',order=['0','1','2','3','4'])

plt.show()

# I don't know why they use word g while using FacetGrid... so I followed the conventions

# %% [markdown]
# #### Using map function on Facetgrid I made many plots

# %% [markdown]
# ## Catplots (Was previously illustrated in the previous Notebook)

# %% [markdown]
# #### Seaborn's FacetGrid() is very powerful and flexible but involves multiple steps to create. The catplot() function is a shortcut to creating FacetGrids. The underlying returned value is a FacetGrid but the process for creating one is much simpler. The single catplot() function takes care of the two step process for you.

# %%
sns.catplot(x='Tuition',col='HIGHDEG',data=college_data,kind='box')

plt.show()

# %% [markdown]
# ## FacetGrid for regression plot

# %%
g = sns.FacetGrid(data=college_data,col='HIGHDEG')
g.map(plt.scatter,'Tuition','SAT_AVG_ALL')

plt.show()

# %% [markdown]
# ## lmplots

# %% [markdown]
# #### The lmplot() function is similar to the catplot() function. It provides a shortcut for plotting regression and scatter plots on FacetGrids. In this example, we create a plot that is similar to the FacetGrid() scatter plot. We have also disabled regression lines with the fit_reg equals False parameter.

# %%
sns.lmplot(data=college_data,x='Tuition',y='SAT_AVG_ALL',col='HIGHDEG',fit_reg=False) # fit_reg = False

plt.show()
# Which is same as before

## --------------------------------------------------------------------- ##
sns.lmplot(data=college_data,x='Tuition',y='SAT_AVG_ALL',col='HIGHDEG',fit_reg=True) # fit_reg = True

plt.show()

# %% [markdown]
# # PairGrid

# %% [markdown]
# ####  PairGrid and pairplot. These plots are similar to the FacetGrid, catplot, and lmplots
# #### The PairGrid plot allows us to build plots that show the relationships between two data elements

# %%
insurance.head()
# Out:
#         State  fatal_collisions  fatal_collisions_speeding  \
# 0     Alabama              18.8                         39
# 1      Alaska              18.1                         41
# 2     Arizona              18.6                         35
# 3    Arkansas              22.4                         18
# 4  California              12.0                         35
#
#    fatal_collisions_alc  fatal_collisions_not_distracted  \
# 0                    30                               96
# 1                    25                               90
# 2                    28                               84
# 3                    26                               94
# 4                    28                               91
#
#    fatal_collisions_no_hist  premiums  insurance_losses Region
# 0                        80    784.55            145.08  South
# 1                        94   1053.48            133.93   West
# 2                        96    899.47            110.35   West
# ...

# %% [markdown]
# ## Making pairgrids

# %%
g = sns.PairGrid(insurance, vars=["fatal_collisions", "premiums"])
g2 = g.map(sns.scatterplot)

plt.show()

# %% [markdown]
# ### Here Iam specifing the diagonal

# %%
g = sns.PairGrid(insurance, vars=["fatal_collisions", "premiums"])
g2 = g.map_diag(sns.histplot)              # main diagonal
g3 = g2.map_offdiag(sns.scatterplot)

plt.show()

# %% [markdown]
# ## Pairplots

# %% [markdown]
# #### Pairplot is a shortcut function that simplifies the PairGrid. First, we define the variables like we did in the previous view. However, instead of mapping the plots, we can pass keywords to the function to specify the kind of plots for the main and off diagonals. The other nice aspect of this function is that it plots a regression line for us. This is a useful feature for visualizing potential relationships in the data.

# %%
sns.pairplot(data=insurance,
        vars=["fatal_collisions", "premiums"],
        kind='scatter')

plt.show()

# %%
sns.pairplot(data=insurance,
        vars=["fatal_collisions", "premiums"],
        kind='scatter',
        hue='Region',
        palette='RdBu',
        diag_kws={'alpha':.5})

plt.show()

# %%
sns.pairplot(data=insurance,
        x_vars=["fatal_collisions_speeding", "fatal_collisions_alc"],
        y_vars=['premiums', 'insurance_losses'],
        kind='scatter',
        hue='Region',
        palette='husl')

plt.show()

# here Iam using 4 data columns to compare with

# %%
sns.pairplot(data=insurance,
             vars=["insurance_losses", "premiums"],
             kind='reg',
             palette='BrBG',
             diag_kind = 'kde',
             hue='Region')

plt.show()

# %% [markdown]
# <h1><center> And this is the end of this Notebook <br>
